# %% [markdown]
# self_training = SelfTrainingClassifier(
#     RandomForestClassifier( random_state=42),
#     threshold=0.5,
#     max_iter=10
# )
#
# ============================================================
# SELF-TRAINING MODEL - Validation Set (FIFA 20) Metrics
# ============================================================
#
# Accuracy:  0.7714
# Precision: 0.4979
# Recall:    0.0649
# F1 Score:  0.1148
# ROC-AUC:   0.6998
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                   precision    recall  f1-score   support
#
# No Big Potential       0.78      0.98      0.87      6242
#    Big Potential       0.50      0.06      0.11      1849
#
#         accuracy                           0.77      8091
#        macro avg       0.64      0.52      0.49      8091
#     weighted avg       0.72      0.77      0.70      8091
#
# ------------------------------------------------------------
# Confusion Matrix:
# ------------------------------------------------------------
#                   Predicted
#                   No BP    BP
# Actual No BP      6121    121
# Actual BP         1729    120

# %% [markdown]
# ============================================================
# SELF-TRAINING MODEL - Validation Set (FIFA 20) Metrics
# ============================================================
#
# Accuracy:  0.7717
# Precision: 0.5070
# Recall:    0.0389
# F1 Score:  0.0723
# ROC-AUC:   0.7000
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                   precision    recall  f1-score   support
#
# No Big Potential       0.78      0.99      0.87      6242
#    Big Potential       0.51      0.04      0.07      1849
#
#         accuracy                           0.77      8091
#        macro avg       0.64      0.51      0.47      8091
#     weighted avg       0.71      0.77      0.69      8091
#
# ------------------------------------------------------------
# Confusion Matrix:
# ------------------------------------------------------------
#                   Predicted
#                   No BP    BP
# Actual No BP      6172     70
# Actual BP         1777     72

# %% [markdown]
# BEST MODEL FOR THE MOMENT
# self_training = SelfTrainingClassifier(
#     RandomForestClassifier(
#         random_state=42,
#         class_weight='balanced',
#         n_estimators=300,  # More trees
#         max_depth=20,  # Deeper trees
#         min_samples_split=5,
#         min_samples_leaf=2,
#         max_features='sqrt',  # Feature subsampling
#         bootstrap=True
#     ),
#     threshold=0.5,
#     max_iter=15,
#     verbose=True  # See progress
# )
# End of iteration 1, added 23832 new labels.
# ============================================================
# SELF-TRAINING MODEL - Validation Set (FIFA 20) Metrics
# ============================================================
#
# Accuracy:  0.7769
# Precision: 0.5297
# Recall:    0.2120
# F1 Score:  0.3028
# ROC-AUC:   0.7183
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                   precision    recall  f1-score   support
#
# No Big Potential       0.80      0.94      0.87      6242
#    Big Potential       0.53      0.21      0.30      1849
#
#         accuracy                           0.78      8091
#        macro avg       0.67      0.58      0.59      8091
#     weighted avg       0.74      0.78      0.74      8091
#
# ------------------------------------------------------------
# Confusion Matrix:
# ------------------------------------------------------------
#                   Predicted
#                   No BP    BP
# Actual No BP      5894    348
# Actual BP         1457    392

# %% [markdown]
# this one also has good metrics
# self_training_gb = SelfTrainingClassifier(
#     GradientBoostingClassifier(
#         random_state=42,
#         learning_rate=0.1,
#         n_estimators=200,
#         max_depth=5
#     ),
#     threshold=0.5,
#     max_iter=15
# )

# %% [markdown]
# XGBoost outperforme any other algorithme for the moment
# self_training_xgb = SelfTrainingClassifier(
#     XGBClassifier(
#         random_state=42,
#         scale_pos_weight=3.0,  # Adjust for class imbalance
#         eval_metric='logloss'
#     ),
#     threshold=0.5,
#     max_iter=15
# )
# ============================================================
# SELF-TRAINING MODEL - Validation Set (FIFA 20) Metrics
# ============================================================
#
# Accuracy:  0.7376
# Precision: 0.4223
# Recall:    0.4029
# F1 Score:  0.4124
# ROC-AUC:   0.7058
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                   precision    recall  f1-score   support
#
# No Big Potential       0.83      0.84      0.83      6242
#    Big Potential       0.42      0.40      0.41      1849
#
#         accuracy                           0.74      8091
#        macro avg       0.62      0.62      0.62      8091
#     weighted avg       0.73      0.74      0.74      8091
#
# ------------------------------------------------------------
# Confusion Matrix:
# ------------------------------------------------------------
#                   Predicted
#                   No BP    BP
# Actual No BP      5223   1019
# Actual BP         1104    745

# %% [markdown]
# 0.8 was the best for the moment

# %% [markdown]
# self_training_xgb = SelfTrainingClassifier(
#     XGBClassifier(
#         random_state=42,
#         scale_pos_weight=3.5,  # Adjust for class imbalance
#         eval_metric='logloss'
#     ),
#     threshold=0.8,
#     max_iter=15
# )
#
# ============================================================
# SELF-TRAINING MODEL - Validation Set (FIFA 20) Metrics
# ============================================================
#
# Accuracy:  0.7426
# Precision: 0.4385
# Recall:    0.4511
# F1 Score:  0.4447
# ROC-AUC:   0.7111
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                   precision    recall  f1-score   support
#
# No Big Potential       0.84      0.83      0.83      6242
#    Big Potential       0.44      0.45      0.44      1849
#
#         accuracy                           0.74      8091
#        macro avg       0.64      0.64      0.64      8091
#     weighted avg       0.75      0.74      0.74      8091
#
# ------------------------------------------------------------
# Confusion Matrix:
# ------------------------------------------------------------
#                   Predicted
#                   No BP    BP
# Actual No BP      5174   1068
# Actual BP         1015    834

# %% [markdown]
# Accuracy:  0.6669
# Precision: 0.3710
# Recall:    0.6577
# F1 Score:  0.4744
# ROC-AUC:   0.7203

# %% [markdown]
# self_training_xgb = SelfTrainingClassifier(
#     XGBClassifier(
#         random_state=42,
#         scale_pos_weight=3.5,  # Adjust for class imbalance
#         eval_metric='logloss',
#         max_depth=4,
#         min_child_weight=3,
#         subsample=0.7,
#         colsample_bytree=0.7,
#         gamma=1,
#         reg_alpha=0.1,
#         reg_lambda=1.0
#     ),
#     threshold=0.9,
#     max_iter=25,
#     verbose=1
# )
#
# End of iteration 1, added 6846 new labels.
# End of iteration 2, added 5163 new labels.
# End of iteration 3, added 3005 new labels.
# End of iteration 4, added 1613 new labels.
# End of iteration 5, added 1104 new labels.
# End of iteration 6, added 723 new labels.
# End of iteration 7, added 525 new labels.
# End of iteration 8, added 357 new labels.
# End of iteration 9, added 297 new labels.
# End of iteration 10, added 229 new labels.
# End of iteration 11, added 187 new labels.
# End of iteration 12, added 191 new labels.
# End of iteration 13, added 129 new labels.
# End of iteration 14, added 100 new labels.
# End of iteration 15, added 131 new labels.
# End of iteration 16, added 96 new labels.
# End of iteration 17, added 92 new labels.
# End of iteration 18, added 91 new labels.
# End of iteration 19, added 82 new labels.
# End of iteration 20, added 71 new labels.
# End of iteration 21, added 71 new labels.
# End of iteration 22, added 46 new labels.
# End of iteration 23, added 39 new labels.
# End of iteration 24, added 69 new labels.
# End of iteration 25, added 42 new labels.
# ============================================================
# SELF-TRAINING MODEL - Validation Set (FIFA 20) Metrics
# ============================================================
#
# Accuracy:  0.6616
# Precision: 0.3670
# Recall:    0.6636
# F1 Score:  0.4727
# ROC-AUC:   0.7195
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                   precision    recall  f1-score   support
#
# No Big Potential       0.87      0.66      0.75      6242
#    Big Potential       0.37      0.66      0.47      1849
#
#         accuracy                           0.66      8091
#        macro avg       0.62      0.66      0.61      8091
#     weighted avg       0.75      0.66      0.69      8091
#
# ------------------------------------------------------------
# Confusion Matrix:
# ------------------------------------------------------------
#                   Predicted
#                   No BP    BP
# Actual No BP      4126   2116
# Actual BP          622   1227

# %% [markdown]
# Accuracy:  0.7386
# Precision: 0.4674
# Recall:    0.4525
# F1 Score:  0.4598
# ROC-AUC:   0.7088
#
# self_training_xgb = SelfTrainingClassifier(
#     XGBClassifier(
#         random_state=42,
#         scale_pos_weight=3.0,  # Adjust for class imbalance
#         eval_metric='logloss'
#     ),
#     threshold=0.5,
#     max_iter=15
# )

# %% [markdown]
# self_training_xgb = SelfTrainingClassifier(
#     XGBClassifier(
#         random_state=42,
#         scale_pos_weight=3,  # Adjust for class imbalance
#         eval_metric='logloss'
#     ),
#     threshold=0.90,
#     max_iter=15
# )
# Accuracy:  0.7533
# Precision: 0.4979
# Recall:    0.4123
# F1 Score:  0.4511
# ROC-AUC:   0.7136

# %%
self_training_xgb = SelfTrainingClassifier(
    XGBClassifier(
        random_state=42,
        scale_pos_weight=3,  # Adjust for class imbalance
        eval_metric='logloss'
    ),
    threshold=0.92,
    max_iter=15
)
Accuracy:  0.7299
Precision: 0.4546
Recall:    0.4938
F1 Score:  0.4734
ROC-AUC:   0.7257

# %%
self_training_xgb = SelfTrainingClassifier(
    XGBClassifier(
        random_state=42,
        scale_pos_weight=3,  # Adjust for class imbalance
        eval_metric='logloss',
        max_depth=4,
        learning_rate=0.05,
        subsample=0.7,
        colsample_bytree=0.7,
        min_child_weight=5,
    gamma=1,
    reg_alpha=0.2,
    reg_lambda=1.0
    ),
    threshold=0.92,
    max_iter=15
)
Accuracy:  0.6643
Precision: 0.3932
Recall:    0.6728
F1 Score:  0.4963
ROC-AUC:   0.7216

# %%
Accuracy:  0.5994
Precision: 0.3381
Recall:    0.6574
F1 Score:  0.4465
ROC-AUC:   0.6785
""" self_training = SelfTrainingClassifier(
   RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    min_samples_split=5,
    min_samples_leaf=4,
    max_features="sqrt",
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
    ),
    threshold=0.9,
    max_iter=3
) """

# %% [markdown]
# THIS IS THE BEST MODAL FOR THE MOMENT THE ONLY ONE THAT IS IN A GOOD ZONE

# %% [markdown]
# xgb_baseline = xgb(
#     n_estimators=300,
#     max_depth=6,
#     learning_rate=0.05,
#     subsample=0.8,
#     colsample_bytree=0.8,
#     reg_alpha=0.1,
#     reg_lambda=1.0,
#     scale_pos_weight=3,
#     eval_metric="logloss",
#     tree_method="hist",
#     random_state=42
# )
#
# self_training = SelfTrainingClassifier(
#     xgb_baseline,
#     threshold=0.8,     # XGBoost gives good confidence scores
#     max_iter=10,
#     verbose=1
# )
# Accuracy:  0.7246
# Precision: 0.4465
# Recall:    0.5032
# F1 Score:  0.4732
# ROC-AUC:   0.7164

# %%
xgb_baseline = xgb(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1.0,
    scale_pos_weight=3,    
    eval_metric="logloss",
    tree_method="hist",
    random_state=42
)

self_training = SelfTrainingClassifier(
    xgb_baseline,
    threshold=0.85,     # XGBoost gives good confidence scores
    max_iter=10,
    verbose=1
)
Accuracy:  0.7276
Precision: 0.4508
Recall:    0.4956
F1 Score:  0.4721
ROC-AUC:   0.7171

# %% [markdown]
# Accuracy:  0.6930
# Precision: 0.4111
# Recall:    0.5747
# F1 Score:  0.4793
# ROC-AUC:   0.7212

# %%
Accuracy:  0.6675
Precision: 0.3901
Recall:    0.6255
F1 Score:  0.4805
ROC-AUC:   0.7174

# %%
Accuracy:  0.6572
Precision: 0.3855
Recall:    0.6645
F1 Score:  0.4880
ROC-AUC:   0.7152

# %%
Accuracy:  0.6641
Precision: 0.3906
Recall:    0.6539
F1 Score:  0.4891
ROC-AUC:   0.7116

# %%
Accuracy:  0.6743
Precision: 0.3945
Recall:    0.6072
F1 Score:  0.4783
ROC-AUC:   0.7088

# %%
xgb_baseline = xgb(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1.0,
    scale_pos_weight=3,    
    eval_metric="logloss",
    tree_method="hist",
    random_state=42
)

self_training = SelfTrainingClassifier(
    xgb_baseline,
    threshold=0.85,     # XGBoost gives good confidence scores
    max_iter=8,
    verbose=1
)

# %%
Accuracy:  0.6572
Precision: 0.3855
Recall:    0.6645
F1 Score:  0.4880
ROC-AUC:   0.7152
