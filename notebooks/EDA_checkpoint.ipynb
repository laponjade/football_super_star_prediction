# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('../data/readyforEDA.csv')
df.head()
# Out:
#    player_id  fifa_version  overall  potential  age  height_cm  weight_kg  \
# 0         16          17.0       70         70   35        177         69
# 1         16          18.0       70         70   36        178         65
# 2         16          19.0       70         70   37        178         65
# 3         41          17.0       88         88   32        171         68
# 4         41          18.0       87         87   33        171         68
#
#    preferred_foot  weak_foot  skill_moves  ...  defending_marking_awareness  \
# 0               1          3            3  ...                           37
# 1               1          3            3  ...                           37
# 2               1          4            3  ...                           68
# 3               1          4            4  ...                           57
# 4               1          4            4  ...                           57
#
#    defending_standing_tackle  defending_sliding_tackle  attacker_position  \
# 0                         46                        42                  1
# 1                         46                        42                  0
# 2                         43                        40                  0
# 3                         57                        56                  0
# 4                         57                        56                  0
#
#    midfielder_position  defender_position  improvement_1_year  \
# 0                    1                  0                 -11
# 1                    1                  0                  26
# 2                    1                  0                   0
# 3                    1                  0                 -34
# 4                    1                  0                  -3
#
#    improvement_2_years  improvement_3_years  big_potential
# 0                   15                    0              0
# 1                    0                    0              0
# 2                    0                    0              0
# 3                  -37                  -65              0
# 4                  -31                  -73              0
#
# [5 rows x 52 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130711 entries, 0 to 130710
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   player_id                    130711 non-null  int64
#  1   fifa_version                 130711 non-null  float64
#  2   overall                      130711 non-null  int64
#  3   potential                    130711 non-null  int64
#  4   age                          130711 non-null  int64
#  5   height_cm                    130711 non-null  int64
#  6   weight_kg                    130711 non-null  int64
#  7   preferred_foot               130711 non-null  int64
#  8   weak_foot                    130711 non-null  int64
#  9   skill_moves                  130711 non-null  int64
#  10  pace                         130711 non-null  float64
#  11  shooting                     130711 non-null  float64
#  12  passing                      130711 non-null  float64
#  13  dribbling                    130711 non-null  float64
#  14  defending                    130711 non-null  float64
#  15  physic                       130711 non-null  float64
#  16  attacking_crossing           130711 non-null  int64
#  17  attacking_finishing          130711 non-null  int64
#  18  attacking_heading_accuracy   130711 non-null  int64
#  19  attacking_short_passing      130711 non-null  int64
#  20  attacking_volleys            130711 non-null  int64
#  21  skill_dribbling              130711 non-null  int64
#  22  skill_curve                  130711 non-null  int64
#  23  skill_fk_accuracy            130711 non-null  int64
#  24  skill_long_passing           130711 non-null  int64
#  25  skill_ball_control           130711 non-null  int64
#  26  movement_acceleration        130711 non-null  int64
#  27  movement_sprint_speed        130711 non-null  int64
#  28  movement_agility             130711 non-null  int64
#  29  movement_reactions           130711 non-null  int64
#  30  movement_balance             130711 non-null  int64
#  31  power_shot_power             130711 non-null  int64
#  32  power_jumping                130711 non-null  int64
#  33  power_stamina                130711 non-null  int64
#  34  power_strength               130711 non-null  int64
#  35  power_long_shots             130711 non-null  int64
#  36  mentality_aggression         130711 non-null  int64
#  37  mentality_interceptions      130711 non-null  int64
#  38  mentality_positioning        130711 non-null  int64
#  39  mentality_vision             130711 non-null  int64
#  40  mentality_penalties          130711 non-null  int64
#  41  mentality_composure          130711 non-null  float64
#  42  defending_marking_awareness  130711 non-null  int64
#  43  defending_standing_tackle    130711 non-null  int64
#  44  defending_sliding_tackle     130711 non-null  int64
#  45  attacker_position            130711 non-null  int64
#  46  midfielder_position          130711 non-null  int64
#  47  defender_position            130711 non-null  int64
#  48  improvement_1_year           130711 non-null  int64
#  49  improvement_2_years          130711 non-null  int64
#  50  improvement_3_years          130711 non-null  int64
#  51  big_potential                130711 non-null  int64
# dtypes: float64(8), int64(44)
# memory usage: 51.9 MB

# %%
df = df[df['improvement_3_years'] != 0]
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41458 entries, 3 to 118466
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    41458 non-null  int64
#  1   fifa_version                 41458 non-null  float64
#  2   overall                      41458 non-null  int64
#  3   potential                    41458 non-null  int64
#  4   age                          41458 non-null  int64
#  5   height_cm                    41458 non-null  int64
#  6   weight_kg                    41458 non-null  int64
#  7   preferred_foot               41458 non-null  int64
#  8   weak_foot                    41458 non-null  int64
#  9   skill_moves                  41458 non-null  int64
#  10  pace                         41458 non-null  float64
#  11  shooting                     41458 non-null  float64
#  12  passing                      41458 non-null  float64
#  13  dribbling                    41458 non-null  float64
#  14  defending                    41458 non-null  float64
#  15  physic                       41458 non-null  float64
#  16  attacking_crossing           41458 non-null  int64
#  17  attacking_finishing          41458 non-null  int64
#  18  attacking_heading_accuracy   41458 non-null  int64
#  19  attacking_short_passing      41458 non-null  int64
#  20  attacking_volleys            41458 non-null  int64
#  21  skill_dribbling              41458 non-null  int64
#  22  skill_curve                  41458 non-null  int64
#  23  skill_fk_accuracy            41458 non-null  int64
#  24  skill_long_passing           41458 non-null  int64
#  25  skill_ball_control           41458 non-null  int64
#  26  movement_acceleration        41458 non-null  int64
#  27  movement_sprint_speed        41458 non-null  int64
#  28  movement_agility             41458 non-null  int64
#  29  movement_reactions           41458 non-null  int64
#  30  movement_balance             41458 non-null  int64
#  31  power_shot_power             41458 non-null  int64
#  32  power_jumping                41458 non-null  int64
#  33  power_stamina                41458 non-null  int64
#  34  power_strength               41458 non-null  int64
#  35  power_long_shots             41458 non-null  int64
#  36  mentality_aggression         41458 non-null  int64
#  37  mentality_interceptions      41458 non-null  int64
#  38  mentality_positioning        41458 non-null  int64
#  39  mentality_vision             41458 non-null  int64
#  40  mentality_penalties          41458 non-null  int64
#  41  mentality_composure          41458 non-null  float64
#  42  defending_marking_awareness  41458 non-null  int64
#  43  defending_standing_tackle    41458 non-null  int64
#  44  defending_sliding_tackle     41458 non-null  int64
#  45  attacker_position            41458 non-null  int64
#  46  midfielder_position          41458 non-null  int64
#  47  defender_position            41458 non-null  int64
#  48  improvement_1_year           41458 non-null  int64
#  49  improvement_2_years          41458 non-null  int64
#  50  improvement_3_years          41458 non-null  int64
#  51  big_potential                41458 non-null  int64
# dtypes: float64(8), int64(44)
# memory usage: 16.8 MB
#     player_id  fifa_version  overall  potential  age  height_cm  weight_kg  \
# 3          41          17.0       88         88   32        171         68
# 4          41          18.0       87         87   33        171         68
# 5          41          19.0       87         87   34        171         68
# 9          80          17.0       76         76   35        170         72
# 19        768          17.0       75         75   31        188         75
#
#     preferred_foot  weak_foot  skill_moves  ...  defending_marking_awareness  \
# 3                1          4            4  ...                           57
# 4                1          4            4  ...                           57
# 5                1          4            4  ...                           67
# 9                0          3            2  ...                           64
# 19               0          3            2  ...                           80
#
#     defending_standing_tackle  defending_sliding_tackle  attacker_position  \
# 3                          57                        56                  0
# 4                          57                        56                  0
# 5                          57                        56                  0
# 9                          66                        65                  0
# 19                         80                        76                  0
#
#     midfielder_position  defender_position  improvement_1_year  \
# 3                     1                  0                 -34
# 4                     1                  0                  -3
# 5                     1                  0                 -28
# 9                     1                  0                  25
# 19                    0                  1                 -31
#
#     improvement_2_years  improvement_3_years  big_potential
# 3                   -37                  -65              0
# 4                   -31                  -73              0
# 5                   -70                 -145              0
# 9                    22                    4              0
# 19                  -55                  -93              0
#
# [5 rows x 52 columns]

# %%
df['big_potential'].value_counts()
# Out:
# big_potential
# 0    31162
# 1    10296
# Name: count, dtype: int64

# %%
att_df = df[df['attacker_position'] == 1]
mid_df = df[df['midfielder_position'] == 1]
def_df = df[df['defender_position'] == 1]

# %%
file_path = '../data/Attackers.csv'
att_df.to_csv(file_path, index=False)

print(f'DataFrame att_df has been saved as {file_path}')

file_path1 = '../data/Midfielders.csv'
mid_df.to_csv(file_path1, index=False)

print(f'DataFrame mid_df has been saved as {file_path1}')

file_path2 = '../data/Defenders.csv'
def_df.to_csv(file_path2, index=False)

print(f'DataFrame def_df has been saved as {file_path2}')
# Out:
# DataFrame att_df has been saved as ../data/Attackers.csv
# DataFrame mid_df has been saved as ../data/Midfielders.csv
# DataFrame def_df has been saved as ../data/Defenders.csv

# %%
independent_variables = ['age', 'height_cm', 'weight_kg', 'weak_foot', 'skill_moves', 'pace', 'shooting',
       'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle',
       'preferred_foot', 'attacker_position', 'midfielder_position',
       'defender_position']

target_variable = "big_potential"
X = df[independent_variables]
y = df[target_variable]

clf = RandomForestClassifier()
clf.fit(X, y)

feature_importance = clf.feature_importances_

threshold = 0.024 

feature_importance_df = pd.DataFrame({'Feature': independent_variables, 'Importance': feature_importance})

selected_features = feature_importance_df[feature_importance_df['Importance'] > threshold]

print(selected_features)
# Out:
#                        Feature  Importance
# 0                          age    0.069927
# 10                      physic    0.025986
# 11          attacking_crossing    0.025689
# 13  attacking_heading_accuracy    0.026757
# 14     attacking_short_passing    0.024123
# 15           attacking_volleys    0.026941
# 16             skill_dribbling    0.024185
# 17                 skill_curve    0.024965
# 18           skill_fk_accuracy    0.025295
# 19          skill_long_passing    0.024652
# 20          skill_ball_control    0.025938
# 23            movement_agility    0.025583
# 24          movement_reactions    0.024397
# 25            movement_balance    0.025558
# 26            power_shot_power    0.025126
# 27               power_jumping    0.028343
# 28               power_stamina    0.027038
# 29              power_strength    0.024604
# 30            power_long_shots    0.024866
# 31        mentality_aggression    0.027110
# 32     mentality_interceptions    0.026769
# 33       mentality_positioning    0.024370
# 34            mentality_vision    0.024103
# 35         mentality_penalties    0.025810
# 36         mentality_composure    0.025363
# 38   defending_standing_tackle    0.024404
# 39    defending_sliding_tackle    0.024688

# %%
selected_features_with_target = df[selected_features['Feature'].values].copy()
selected_features_with_target[target_variable] = df[target_variable]

correlation_with_target = selected_features_with_target.corr()[target_variable].drop(target_variable)

sorted_features = correlation_with_target.abs().sort_values(ascending=False).index

plt.figure(figsize=(12, 6))
sns.barplot(x=correlation_with_target[sorted_features].index, y=correlation_with_target[sorted_features].values, palette="coolwarm_r")  # "_r" reverses the color order

plt.xlabel("Selected Features")
plt.ylabel("Correlation with Target Variable")
plt.title("Correlation between Selected Features and Target Variable")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# /var/folders/06/_wjmyc_97cn0n7hx93prnq000000gn/T/ipykernel_32862/2299784970.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_with_target[sorted_features].index, y=correlation_with_target[sorted_features].values, palette="coolwarm_r")  # "_r" reverses the color order

# %%
# Create df_selected with only the sorted features and the target variable
df_selected = df[sorted_features.tolist() + [target_variable]].copy()
df_selected["big_potential"].value_counts()
# Out:
# big_potential
# 0    31162
# 1    10296
# Name: count, dtype: int64

# %%
len(df_selected.columns)
# Out:
# 28

# %%
df_selected.head()
# Out:
#     age  physic  mentality_aggression  mentality_interceptions  power_stamina  \
# 3    32    60.0                    58                       68             64
# 4    33    58.0                    58                       66             58
# 5    34    57.0                    58                       66             55
# 9    35    66.0                    87                       68             51
# 19   31    66.0                    70                       81             55
#
#     power_strength  power_jumping  defending_standing_tackle  \
# 3               59             54                         57
# 4               58             52                         57
# 5               58             47                         57
# 9               64             72                         66
# 19              69             70                         80
#
#     defending_sliding_tackle  attacking_heading_accuracy  ...  skill_curve  \
# 3                         56                          54  ...           80
# 4                         56                          54  ...           80
# 5                         56                          54  ...           80
# 9                         65                          43  ...           81
# 19                        76                          74  ...           49
#
#     movement_balance  attacking_volleys  power_long_shots  mentality_vision  \
# 3                 86                 74                74                94
# 4                 84                 74                71                94
# 5                 84                 74                71                94
# 9                 84                 69                77                77
# 19                63                 19                40                46
#
#     mentality_penalties  movement_agility  attacking_short_passing  \
# 3                    71                82                       92
# 4                    71                79                       92
# 5                    71                79                       92
# 9                    85                66                       83
# 19                   35                52                       62
#
#     mentality_positioning  big_potential
# 3                      85              0
# 4                      84              0
# 5                      84              0
# 9                      67              0
# 19                     29              0
#
# [5 rows x 28 columns]

# %%
file_path = '../data/feature_engineered_data.csv'
df_selected.to_csv(file_path, index=False)

print(f'DataFrame df_selected has been saved as {file_path}')
# Out:
# DataFrame df_selected has been saved as ../data/feature_engineered_data.csv
